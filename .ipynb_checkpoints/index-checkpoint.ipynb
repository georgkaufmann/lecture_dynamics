# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">AG Dynamics of the Earth</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Juypter notebooks</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# </tr>
# </table>

# %% [markdown]
# # Machine learning
# ----
# *Georg Kaufmann,
# Geophysics Section,
# Institute of Geological Sciences,
# Freie Universität Berlin,
# Germany*
#
# **jupyter notebooks** on **machine learning**.
#
# Chapters:
# 1. [**Introduction**](01_intro.ipynb)
# 2. [**Workflow**](02_workflow.ipynb)
# 3. **Iris data set**
#     - [Description](03_iris1.ipynb)
#     - [Preparation](03_iris2.ipynb)
#     - [Statistics](03_iris3.ipynb)
#     - **Classification task**
#         - [Natural neighbors](03_classification_NaturalNeighbors1.ipynb)
#         - [Logistic regression](03_classification_LogisticRegression1.ipynb)
#     - **Regression task**
#         - [Linear regression](03_regression1.ipynb)
#         - [Polynomial regression](03_regression2.ipynb)
#         - [2D linear regression](03_regression3.ipynb)
#     - **Feature reduction**
#         - [Principal component analysis](03_features1.ipynb)
#     - **Unsupervised learning**
#
# 4. **Geophysical data sets**
#     - [Borehole data](04_Boreholes1.ipynb)
#     - [Hand-written digits](04_Hand-writtenDigits.ipynb)
#     - ...
#
# 5. **Explanation of methods**
#     - [Preparation](05_Preparation.ipynb)
#     - [Linear regression](05_Linear_Regression.ipynb)
#     - [Natural neighbors](05_NaturalNeighbors.ipynb)
#     - [Logistic regression](05_LogisticRegression.ipynb)
