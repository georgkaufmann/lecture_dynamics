# %% [markdown]
# <table>
# <tr><td><img style="height: 150px;" src="images/geo_hydro1.jpg"></td>
# <td bgcolor="#FFFFFF">
#     <p style="font-size: xx-large; font-weight: 900; line-height: 100%">AG Dynamics of the Earth</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Juypter notebooks</p>
#     <p style="font-size: large; color: rgba(0,0,0,0.5);">Georg Kaufmann</p>
#     </td>
# </tr>
# </table>

# %% [markdown]
# # Machine learning: Statistics of the data set
# ----
# *Georg Kaufmann,
# Geophysics Section,
# Institute of Geological Sciences,
# Freie Universität Berlin,
# Germany*

# %% [markdown]
# We now look re-read our cleaned dataset and present some statistics.
#
# First, load some `python` libraries and load the cleaned `iris data set` as `pandas` data frame `df`:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap 
import pandas as pd
import seaborn as sns

# %% [markdown]
# We read our cleaned data set with `pandas`:

# %%
df = pd.read_csv('data/iris_cleaned.csv',encoding='iso-8859-15')

# %% [markdown]
# ## Have a look at the **header** of the data set

# %%
df.head(10)

# %% [markdown]
# ## Print general **statistical information** of the data set

# %%
df.describe()

# %% [markdown]
# ## **Univariate** distribution of features in a **histogram plot**

# %%
df.hist(figsize=(10, 10))
plt.show()

# %% [markdown]
# ## Uni- and bi-variate feature of pair of features

# %%
sns.jointplot(x=df['sepal length'], y=df['petal length'])
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
corrmat = df.corr()
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# ## Finally a uni-bivariate feature matrix
# We first need to rename the labels to numerical values ...

# %%
df['class']
df.loc[(df['class'] == 'Iris-setosa'),'class']=0
df.loc[(df['class'] == 'Iris-versicolor'),'class']=1
df.loc[(df['class'] == 'Iris-virginica'),'class']=2
x=df['class'].array
print(x.ndim,x.shape,x)

# %%
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
x=pd.plotting.scatter_matrix(df[['sepal length','sepal width','petal length','petal width']],
                           marker='o',c=df['class'],cmap=cmap_bold, figsize=(15, 15))

# %% [markdown]
# ... done
